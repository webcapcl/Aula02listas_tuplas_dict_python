# %% [markdown]
# <a href="https://colab.research.google.com/github/webcapcl/Aula02listas_tuplas_dict_python/blob/main/Atividade02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
materias = ['Matemática','História','Biologia']
notas = (8.5 , 7.0 , 9.2)
aluno = {'nome:': 'Carlos', 'Idade:': 21, 'Curso:': 'Engenharia'}

print("Matérias:", materias)
print("Notas:", notas)
print("Informações do Aluno", aluno)
# Out:
# Matérias: ['Matemática', 'História', 'Biologia']
# Notas: (8.5, 7.0, 9.2)
# Informações do Aluno {'nome:': 'Carlos', 'Idade:': 21, 'Curso:': 'Engenharia'}

# %%
acessorios = ['Som','Milhas','Adesivos']
especificacao = (" potencia_do_motor: 82", 'capacidade_tanque:52')
carro = {'Marca:': 'Fiat', 'Modelo:' : 'Palio', 'Ano:' : 2018}

print("Acessórios", acessorios)
print("As especificacoes",especificacao )
print("Carro", carro)
# Out:
# Acessórios ['Som', 'Milhas', 'Adesivos']
# As especificacoes (' potencia_do_motor: 82', 'capacidade_tanque:52')
# Carro {'Marca:': 'Fiat', 'Modelo:': 'Palio', 'Ano:': 2018}
